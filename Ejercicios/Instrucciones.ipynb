# %% [markdown]
# # Instrucciones *actividad 1*:

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('data/client_dataset.csv',sep=';')

# %%
dataset.head(20)
# Out:
#     idClient  Score CountryLocation  Gender  Age  Tenure  Games Balance
# 0          1    619          France  Female   42       2           0.00  \
# 1          2    608           Spain  Female   41       1       83807.86
# 2          3    502          France  Female   42       8      159660.80
# 3          4    699          France  Female   39       1           0.00
# 4          5    850           Spain  Female   43       2      125510.82
# 5          6    645           Spain    Male   44       8      113755.78
# 6          7    822          France    Male   50       7           0.00
# 7          8    376         Germany  Female   29       4      115046.74
# 8          9    501          France    Male   44       4      142051.07
# 9         10    684          France    Male   27       2      134603.88
# 10        11    528          France    Male   31       6      102016.72
# 11        12    497           Spain    Male   24       3           0.00
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   idClient          10000 non-null  int64
#  1   Score             10000 non-null  int64
#  2   CountryLocation   10000 non-null  object
#  3   Gender            10000 non-null  object
#  4   Age               10000 non-null  int64
#  5   Tenure            10000 non-null  int64
#  6   Games Balance     10000 non-null  float64
#  7   NumOfProducts     10000 non-null  int64
#  8   HasPremiumAccess  10000 non-null  int64
#  9   IsActiveMember    10000 non-null  int64
#  10  Cumulative score  10000 non-null  float64
#  11  Churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# ## Carga de datos
# Se pretende realizar una [carga de los datos](https://learn.microsoft.com/es-es/power-bi/connect-data/service-comma-separated-value-files) para ver el funcionamiento básico teniendo un dataset pretratado o no.

# %% [markdown]
# ### Transformación de los datos
# Power BI permite hacer transformaciones de los datos previas a su carga, añadiendo una especie de pipline.
#
# Formas de transformar los datos:
# - Mediante lenguaje M
# - Realizando cálculos
# - Scripts de R o [Python](https://learn.microsoft.com/es-es/power-bi/connect-data/desktop-python-scripts)

# %% [markdown]
# 1. Crear una nueva columna que divida en rangos de edades:

# %%
# Script python
import pandas
import matplotlib

def categorize_age(age):
    if age < 18:
        return "Minors"
    elif 18 <= age <= 70:
        return "Adults"
    else:
        return "Seniors"

# Aplicar la función a la columna "Age"
dataset['AgeClf'] = dataset['Age'].apply(categorize_age)

# %% [markdown]
# 2. Crear de la misma manera una columna llamada 'CumulativeScoreClf' tal que nombre como 'High' los que estén por encima de la media y 'Low' los que estén por debajo:

# %% [markdown]
# 3. Eliminar una columna cualquiera como 'CumulativeScore'.

# %% [markdown]
# Una vez realizado estos pasos, procedemos a cargar los datos

# %% [markdown]
# ## Crear visualizaciones

# %% [markdown]
# **Propuesta:**
#
# 1. Cargar un logo en la parte superior
#
# 2. Usar elemento de forma, proporcionando formato
#
# 3. Elegir estilo
#
# 4. Prueba a crear 2 visualizaciones y justifica tu elección

# %% [markdown]
# # Instrucciones *actividad 2*:

# %% [markdown]
# ### Conectar con una base de datos en Azure
#
# ### Cargar los datos directamente
#
# ### Visualizacion prueba
#
# ### Publicar (extra)
